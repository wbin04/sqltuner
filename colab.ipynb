# %%
import torch
import sys
import os

print(f"🖥️  Đang chạy trên hệ điều hành: {sys.platform}")

# Kiểm tra xem có phải môi trường Colab không
if 'google.colab' in sys.modules:
    print("☁️  Đã xác nhận: Đang chạy trên Runtime của Google Colab")
else:
    print("⚠️  Cảnh báo: Có vẻ bạn đang chạy trên máy Local (hoặc chưa import google.colab)")

print("-" * 30)

# Kiểm tra GPU
if torch.cuda.is_available():
    print(f"✅ GPU đang hoạt động: {torch.cuda.get_device_name(0)}")
    print(f"📦 VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
    print(f"🚀 CUDA Version: {torch.version.cuda}")
else:
    print("❌ Không tìm thấy GPU. Hãy kiểm tra lại kết nối Kernel ở góc trên bên phải VS Code.")
# Out:
# 🖥️  Đang chạy trên hệ điều hành: linux
# ☁️  Đã xác nhận: Đang chạy trên Runtime của Google Colab
# ------------------------------
# ✅ GPU đang hoạt động: Tesla T4
# 📦 VRAM: 15.83 GB
# 🚀 CUDA Version: 12.6
